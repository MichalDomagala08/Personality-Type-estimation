# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Michał\Downloads\mbti-type\mbti_1.csv",sep = ",", engine = "python")
df
# Out:
#       type                                              posts
# 0     INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...
# 1     ENTP  'I'm finding the lack of me in these posts ver...
# 2     INTP  'Good one  _____   https://www.youtube.com/wat...
# 3     INTJ  'Dear INTP,   I enjoyed our conversation the o...
# 4     ENTJ  'You're fired.|||That's another silly misconce...
# ...    ...                                                ...
# 8670  ISFP  'https://www.youtube.com/watch?v=t8edHB_h908||...
# 8671  ENFP  'So...if this thread already exists someplace ...
# 8672  INTP  'So many questions when i do these things.  I ...
# 8673  INFP  'I am very conflicted right now when it comes ...
# 8674  INFP  'It has been too long since I have been on per...
#
# [8675 rows x 2 columns]

# %%
from matplotlib import cm

cnt_srs = df['type'].value_counts()
viridis = cm.get_cmap('plasma', 12)
colors = viridis(np.flip(np.linspace(0, 1, 16)))
plt.figure(figsize=(12,4))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8,palette=colors)
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Types', fontsize=12)
plt.show()

# %%
from matplotlib import cm

cnt_srs = df['type'].value_counts()
viridis = cm.get_cmap('plasma', 12)
colors = viridis(np.flip(np.linspace(0, 1, 16)))
plt.figure(figsize=(12,4))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8,palette=colors)
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Types', fontsize=12)
plt.show()

# %%
def words_per_post():

    df['words_per_post'] = 0
    for i in range(len(df.index)):
        df['words_per_post'].loc[i] = len(df["posts"].loc[i].split())/50
        #print(len(df["posts"].loc[i].split())/50)

def Average_frase_per_person(frase):
    df["{} per Post".format(frase)] = 0
    for i in range(len(df.index)):
        df["{} per Post".format(frase)].loc[i]  = df["posts"].loc[i].count(frase)/50

# %%
#Cecha 1: Ile słów na post używa dana osoba?

words_per_post()
df
# Out:
# C:\Program Files (x86)\Anaconda\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#       type                                              posts  words_per_post
# 0     INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...           11.12
# 1     ENTP  'I'm finding the lack of me in these posts ver...           23.40
# 2     INTP  'Good one  _____   https://www.youtube.com/wat...           16.72
# 3     INTJ  'Dear INTP,   I enjoyed our conversation the o...           21.28
# 4     ENTJ  'You're fired.|||That's another silly misconce...           19.34
# ...    ...                                                ...             ...
# 8670  ISFP  'https://www.youtube.com/watch?v=t8edHB_h908||...           15.92
# 8671  ENFP  'So...if this thread already exists someplace ...           26.18
# 8672  INTP  'So many questions when i do these things.  I ...           18.96
# 8673  INFP  'I am very conflicted right now when it comes ...           34.10
# 8674  INFP  'It has been too long since I have been on per...           27.22
#
# [8675 rows x 3 columns]

# %%
#Cecha 2: Ile średnio wielokropków na post używa dana osoba?

Average_frase_per_person('...')
df
# Out:
# C:\Program Files (x86)\Anaconda\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#       type                                              posts  words_per_post  \
# 0     INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...           11.12
# 1     ENTP  'I'm finding the lack of me in these posts ver...           23.40
# 2     INTP  'Good one  _____   https://www.youtube.com/wat...           16.72
# 3     INTJ  'Dear INTP,   I enjoyed our conversation the o...           21.28
# 4     ENTJ  'You're fired.|||That's another silly misconce...           19.34
# ...    ...                                                ...             ...
# 8670  ISFP  'https://www.youtube.com/watch?v=t8edHB_h908||...           15.92
# 8671  ENFP  'So...if this thread already exists someplace ...           26.18
# 8672  INTP  'So many questions when i do these things.  I ...           18.96
# 8673  INFP  'I am very conflicted right now when it comes ...           34.10
# 8674  INFP  'It has been too long since I have been on per...           27.22
#
#       ... per Post
# 0             0.30
# 1             0.38
# 2             0.26
# 3             0.52
# 4             0.42
# ...            ...
# 8670          0.14
# 8671          0.82
# 8672          0.38
# 8673          0.94
# 8674          0.48
#
# [8675 rows x 4 columns]

# %%
#Cecha 3: Ile średnio linków na post używa dana osoba?
Average_frase_per_person('http')
df
# Out:
# C:\Program Files (x86)\Anaconda\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#       type                                              posts  words_per_post  \
# 0     INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...           11.12
# 1     ENTP  'I'm finding the lack of me in these posts ver...           23.40
# 2     INTP  'Good one  _____   https://www.youtube.com/wat...           16.72
# 3     INTJ  'Dear INTP,   I enjoyed our conversation the o...           21.28
# 4     ENTJ  'You're fired.|||That's another silly misconce...           19.34
# ...    ...                                                ...             ...
# 8670  ISFP  'https://www.youtube.com/watch?v=t8edHB_h908||...           15.92
# 8671  ENFP  'So...if this thread already exists someplace ...           26.18
# 8672  INTP  'So many questions when i do these things.  I ...           18.96
# 8673  INFP  'I am very conflicted right now when it comes ...           34.10
# 8674  INFP  'It has been too long since I have been on per...           27.22
#
#       ... per Post  http per Post
# 0             0.30           0.48
# 1             0.38           0.20
# 2             0.26           0.10
# 3             0.52           0.04
# 4             0.42           0.12
# ...            ...            ...
# 8670          0.14           0.14
# 8671          0.82           0.04
# 8672          0.38           0.04
# 8673          0.94           0.00
# 8674          0.48           0.06
#
# [8675 rows x 5 columns]

# %%
#Cecha 4: Ile średnio frazy 'Muzyka' na post używa dana osoba?

Average_frase_per_person('music')
df
# Out:
# C:\Program Files (x86)\Anaconda\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#       type                                              posts  words_per_post  \
# 0     INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...           11.12
# 1     ENTP  'I'm finding the lack of me in these posts ver...           23.40
# 2     INTP  'Good one  _____   https://www.youtube.com/wat...           16.72
# 3     INTJ  'Dear INTP,   I enjoyed our conversation the o...           21.28
# 4     ENTJ  'You're fired.|||That's another silly misconce...           19.34
# ...    ...                                                ...             ...
# 8670  ISFP  'https://www.youtube.com/watch?v=t8edHB_h908||...           15.92
# 8671  ENFP  'So...if this thread already exists someplace ...           26.18
# 8672  INTP  'So many questions when i do these things.  I ...           18.96
# 8673  INFP  'I am very conflicted right now when it comes ...           34.10
# 8674  INFP  'It has been too long since I have been on per...           27.22
#
#       ... per Post  http per Post  music per Post
# 0             0.30           0.48            0.02
# 1             0.38           0.20            0.00
# 2             0.26           0.10            0.00
# 3             0.52           0.04            0.02
# 4             0.42           0.12            0.02
# ...            ...            ...             ...
# 8670          0.14           0.14            0.00
# 8671          0.82           0.04            0.00
# 8672          0.38           0.04            0.00
# 8673          0.94           0.00            0.00
# 8674          0.48           0.06            0.00
#
# [8675 rows x 6 columns]

# %%
#Cecha 5: Ile średnio obrazków na post używa dana osoba?

Average_frase_per_person('jpg')
df
# Out:
# C:\Program Files (x86)\Anaconda\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#       type                                              posts  words_per_post  \
# 0     INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...           11.12
# 1     ENTP  'I'm finding the lack of me in these posts ver...           23.40
# 2     INTP  'Good one  _____   https://www.youtube.com/wat...           16.72
# 3     INTJ  'Dear INTP,   I enjoyed our conversation the o...           21.28
# 4     ENTJ  'You're fired.|||That's another silly misconce...           19.34
# ...    ...                                                ...             ...
# 8670  ISFP  'https://www.youtube.com/watch?v=t8edHB_h908||...           15.92
# 8671  ENFP  'So...if this thread already exists someplace ...           26.18
# 8672  INTP  'So many questions when i do these things.  I ...           18.96
# 8673  INFP  'I am very conflicted right now when it comes ...           34.10
# 8674  INFP  'It has been too long since I have been on per...           27.22
#
#       ... per Post  http per Post  music per Post  jpg per Post
# 0             0.30           0.48            0.02          0.12
# 1             0.38           0.20            0.00          0.02
# 2             0.26           0.10            0.00          0.00
# 3             0.52           0.04            0.02          0.00
# 4             0.42           0.12            0.02          0.04
# ...            ...            ...             ...           ...
# 8670          0.14           0.14            0.00          0.02
# 8671          0.82           0.04            0.00          0.00
# 8672          0.38           0.04            0.00          0.00
# 8673          0.94           0.00            0.00          0.00
# 8674          0.48           0.06            0.00          0.00
#
# [8675 rows x 7 columns]

# %%
#Cecha 6: Ile średnio SŁowa 'I' na post używa dana osoba?
#Wzięte z Analizy częstości występowania

Average_frase_per_person('I')
df
# Out:
# C:\Program Files (x86)\Anaconda\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#       type                                              posts  words_per_post  \
# 0     INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...           11.12
# 1     ENTP  'I'm finding the lack of me in these posts ver...           23.40
# 2     INTP  'Good one  _____   https://www.youtube.com/wat...           16.72
# 3     INTJ  'Dear INTP,   I enjoyed our conversation the o...           21.28
# 4     ENTJ  'You're fired.|||That's another silly misconce...           19.34
# ...    ...                                                ...             ...
# 8670  ISFP  'https://www.youtube.com/watch?v=t8edHB_h908||...           15.92
# 8671  ENFP  'So...if this thread already exists someplace ...           26.18
# 8672  INTP  'So many questions when i do these things.  I ...           18.96
# 8673  INFP  'I am very conflicted right now when it comes ...           34.10
# 8674  INFP  'It has been too long since I have been on per...           27.22
#
#       ... per Post  http per Post  music per Post  jpg per Post  I per Post
# 0             0.30           0.48            0.02          0.12        0.46
# 1             0.38           0.20            0.00          0.02        2.02
# 2             0.26           0.10            0.00          0.00        0.98
# 3             0.52           0.04            0.02          0.00        1.74
# 4             0.42           0.12            0.02          0.04        0.92
# ...            ...            ...             ...           ...         ...
# 8670          0.14           0.14            0.00          0.02        1.02
# 8671          0.82           0.04            0.00          0.00        2.40
# 8672          0.38           0.04            0.00          0.00        0.98
# 8673          0.94           0.00            0.00          0.00        3.22
# 8674          0.48           0.06            0.00          0.00        2.52
#
# [8675 rows x 8 columns]

# %%
def heatmap(values, xlabel, ylabel, xticklabels, yticklabels, cmap=None,
            vmin=None, vmax=None, ax=None, fmt="%0.2f"):
    if ax is None:
        ax = plt.gca()
    # plot the mean cross-validation scores
    img = ax.pcolor(values, cmap=cmap, vmin=vmin, vmax=vmax)
    img.update_scalarmappable()
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_xticks(np.arange(len(xticklabels)) + .5)
    ax.set_yticks(np.arange(len(yticklabels)) + .5)
    ax.set_xticklabels(xticklabels)
    ax.set_yticklabels(yticklabels)
    ax.set_aspect(1)

    for p, color, value in zip(img.get_paths(), img.get_facecolors(),
                               img.get_array()):
        x, y = p.vertices[:-2, :].mean(0)
        if np.mean(color[:3]) > 0.5:
            c = 'k'
        else:
            c = 'w'
        ax.text(x, y, fmt % value, color=c, ha="center", va="center")
    return img

# %% [markdown]
# ### Grid_1 --> Zwyczajna absolutnie klasyfikacja

# %%
XX = df.drop(['type','posts'], axis=1).values
yy = df['type'].values



print(XX.shape)
print(yy.shape)

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(XX,yy,test_size = 0.1, random_state=42)
# Out:
# (8675, 6)
# (8675,)

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import chi2


bestfeatures = SelectKBest(score_func=chi2, k=6)
fit = bestfeatures.fit(X_train,y_train)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(df.drop(['type','posts'], axis=1).columns)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(6,'Score'))  #print 10 best features
# Out:
#             Specs       Score
# 0  words_per_post  219.272107
# 5      I per Post   54.593654
# 1    ... per Post   22.173564
# 2   http per Post   13.328238
# 3  music per Post    6.382853
# 4    jpg per Post    1.907333

# %%
from sklearn.model_selection import StratifiedKFold
seed=123
kfold = StratifiedKFold(n_splits=5, random_state=seed)

param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}
param_grid2 = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'penalty': ['none','l2']}
param_grid3 = {'max_leaf_nodes': [10, 16, 32, 64, 80]}

param_grid4 = {'n_estimators': [100,200,300,400,500,600,700,800,900,1000],'max_leaf_nodes' : [2,48,16,32,64]}


from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

grid_1 = GridSearchCV(SVC(kernel = 'rbf',probability=True), param_grid, cv=kfold, return_train_score=True)
grid_2 = GridSearchCV(LogisticRegression(), param_grid2, cv=kfold, return_train_score=True)
grid_3 = GridSearchCV(ExtraTreesClassifier(), param_grid4, cv=kfold, return_train_score=True)


grid_1.fit(X_train, y_train)
print(grid_1.best_params_)

grid_2.fit(X_train, y_train)
print(grid_2.best_params_)

grid_3.fit(X_train, y_train)
print(grid_3.best_params_)

# %%
#Pokazujemy Dokładność Modelu

from sklearn import  metrics

models = []
models.append(('SVM rbf', grid_1.best_estimator_))
models.append(('LogReg', grid_2.best_estimator_))
models.append(('RND', grid_3.best_estimator_))


precision_score = []
recall_score = []
f1_score = []
accuracy_score = []
for name, model in models:
    print(name)
    print("R^2: {}".format(metrics.precision_score(y_test, model.predict(X_test),average='micro') ))
    print("recall_score: {}".format( metrics.recall_score(y_test, model.predict(X_test),average='micro') ))
    print("f1_score: {}".format( metrics.f1_score(y_test, model.predict(X_test),average='micro') ))
    print("accuracy_score: {}".format( metrics.accuracy_score(y_test, model.predict(X_test)) ))
    precision_score.append(metrics.precision_score(y_test, model.predict(X_test),average='micro'))
    recall_score.append(metrics.recall_score(y_test, model.predict(X_test),average='micro'))
    f1_score.append( metrics.f1_score(y_test, model.predict(X_test),average='micro'))
    accuracy_score.append(metrics.accuracy_score(y_test, model.predict(X_test)))

    import seaborn as sn
    import pandas as pd
    import matplotlib.pyplot as plt
    array =metrics.confusion_matrix(y_test, model.predict(X_test))

    personality_types = np.unique(y_test)

    df_cm = pd.DataFrame(array, index = [i for i in personality_types],
                      columns = [i for i in personality_types])

    plt.figure(figsize = (15,15))
    heatmap(array, xlabel='True', xticklabels=personality_types, ylabel='Predicted', yticklabels=personality_types, cmap="plasma")
    plt.show()

# %%
print("SVM")
results1 = pd.DataFrame(grid_1.cv_results_)

scores1 = np.array(results1.mean_test_score).reshape(6, 6)

heatmap(scores1, xlabel='gamma', xticklabels=param_grid['gamma'], ylabel='C', yticklabels=param_grid['C'], cmap="plasma")
plt.show()
print("LogReg")

results2 = pd.DataFrame(grid_2.cv_results_)

scores2 = np.array(results2.mean_test_score).reshape(6, 2)

heatmap(scores2, xlabel='gamma', xticklabels=param_grid2['penalty'], ylabel='C', yticklabels=param_grid2['C'], cmap="plasma")
plt.show()
print("ETC")

results3 = pd.DataFrame(grid_3.cv_results_)

scores3 = np.array(results3.mean_test_score).reshape(5, 10)

heatmap(scores3, xlabel='n_estimators', xticklabels=param_grid4['n_estimators'], ylabel='max_leaf_nodes', yticklabels=param_grid4['max_leaf_nodes'], cmap="plasma")
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import chi2
from imblearn.under_sampling import NearMiss
from imblearn.over_sampling import SMOTE

XX = df.drop(['type','posts','clean_posts','I-E','N-S','T-F','J-P'], axis=1).values
yy = df['type'].values

print(XX.shape)
print(yy.shape)

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(XX,yy,test_size = 0.1, random_state=42)

nm1 = NearMiss(version=1)
sm = SMOTE()
X_train_res, y_train_res = sm.fit_sample(X_train, y_train)
#X_test_res, y_test_res = sm.fit_sample(X_test, y_test)

from sklearn.preprocessing import StandardScaler

X_std = StandardScaler().fit_transform(X_train_res)
X_std_test = StandardScaler().fit_transform(X_test)


from sklearn.decomposition import PCA
model = PCA()

pca_features_train = model.fit_transform(X_std) # dwa wymiary, wiec rzutowanie jest na dwa wymiary
pca_features_test = model.fit_transform(X_std_test)

print(pca_features.shape)
X_train_res = pca_features_train
X_test = pca_features_test
#print(y_train_res)
print(y_test.shape)
# Out:
# (8675, 6)
# (8675,)
# (26528, 6)
# (868,)

# %% [markdown]
# ### Grid2 --> Resampling normalnie

# %%
from sklearn.model_selection import StratifiedKFold
seed=123
kfold = StratifiedKFold(n_splits=5, random_state=seed)

param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}
param_grid2 = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'penalty': ['none','l2']}
param_grid3 = {'max_leaf_nodes': [10, 16, 32, 64, 80]}

param_grid4 = {'n_estimators': [100,200,300,400,500,600,700,800,900,1000],'max_leaf_nodes' : [2,48,16,32,64]}
from sklearn.ensemble import ExtraTreesClassifier


from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

#grid_1_res_normal = GridSearchCV(SVC(kernel = 'rbf',probability=True), param_grid, cv=kfold, return_train_score=True)
grid_2_res_normal = GridSearchCV(LogisticRegression(), param_grid2, cv=kfold, return_train_score=True)
grid_3_res_normal = GridSearchCV(ExtraTreesClassifier(), param_grid4, cv=kfold, return_train_score=True)


#grid_1_res_normal.fit(X_train_res, y_train_res)
#print(grid_1_res_normal.best_params_)

grid_2_res_normal.fit(X_train_res, y_train_res)
print(grid_2_res_normal.best_params_)

grid_3_res_normal.fit(X_train_res, y_train_res)
print(grid_3_res_normal.best_params_)
# Out:
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# {'C': 100, 'penalty': 'l2'}
# {'max_leaf_nodes': 64, 'n_estimators': 400}

# %%
from sklearn.model_selection import StratifiedKFold
seed=123
kfold = StratifiedKFold(n_splits=5, random_state=seed)
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV


param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}

grid_1_res_normal = GridSearchCV(SVC(kernel = 'rbf',probability=True), param_grid, cv=kfold, return_train_score=True)
grid_1_res_normal.fit(X_train_res, y_train_res)
print(grid_1_res_normal.best_params_)
# Out:
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning

# %%
#Pokazujemy Dokładność Modelu


from sklearn import  metrics

models_res = []
#models_res.append(('SVM rbf', grid_1_res_normal.best_estimator_))
models_res.append(('LogReg', grid_2_res_normal.best_estimator_))
models_res.append(('RND', grid_3_res_normal.best_estimator_))




precision_score = []
recall_score = []
f1_score = []
accuracy_score = []
for name, model in models_res:
    print(name)
    print("R^2: {}".format(metrics.precision_score(y_test, model.predict(X_test),average='micro') ))
    print("recall_score: {}".format( metrics.recall_score(y_test, model.predict(X_test),average='micro') ))
    print("f1_score: {}".format( metrics.f1_score(y_test, model.predict(X_test),average='micro') ))
    print("accuracy_score: {}".format( metrics.accuracy_score(y_test, model.predict(X_test)) ))
    precision_score.append(metrics.precision_score(y_test, model.predict(X_test),average='micro'))
    recall_score.append(metrics.recall_score(y_test, model.predict(X_test),average='micro'))
    f1_score.append( metrics.f1_score(y_test, model.predict(X_test),average='micro'))
    accuracy_score.append(metrics.accuracy_score(y_test, model.predict(X_test)))
    
    import seaborn as sn
    import pandas as pd
    import matplotlib.pyplot as plt
    array =metrics.confusion_matrix(y_test, model.predict(X_test))

    personality_types = np.unique(y_test)

    df_cm = pd.DataFrame(array, index = [i for i in personality_types],
                      columns = [i for i in personality_types])

    plt.figure(figsize = (15,15))
    heatmap(array, xlabel='True', xticklabels=personality_types, ylabel='Predicted', yticklabels=personality_types, cmap="plasma")
    plt.show()
# Out:
# LogReg
# R^2: 0.04953917050691244
# recall_score: 0.04953917050691244
# f1_score: 0.04953917050691244
# accuracy_score: 0.04953917050691244
# RND
# R^2: 0.08064516129032258
# recall_score: 0.08064516129032258
# f1_score: 0.08064516129032258
# accuracy_score: 0.08064516129032258

# %%
"""print("SVM")
results1 = pd.DataFrame(grid_1_res_normal.cv_results_)

scores1 = np.array(results1.mean_test_score).reshape(6, 6)

heatmap(scores1, xlabel='gamma', xticklabels=param_grid['gamma'], ylabel='C', yticklabels=param_grid['C'], cmap="plasma")
plt.show()"""
print("LogReg")

results2 = pd.DataFrame(grid_2_res_normal.cv_results_)

scores2 = np.array(results2.mean_test_score).reshape(6, 2)

heatmap(scores2, xlabel='gamma', xticklabels=param_grid2['penalty'], ylabel='C', yticklabels=param_grid2['C'], cmap="plasma")
plt.show()
print("ETC")

results3 = pd.DataFrame(grid_3_res_normal.cv_results_)

scores3 = np.array(results3.mean_test_score).reshape(5, 10)

heatmap(scores3, xlabel='n_estimators', xticklabels=param_grid4['n_estimators'], ylabel='max_leaf_nodes', yticklabels=param_grid4['max_leaf_nodes'], cmap="plasma")
plt.show()
# Out:
# LogReg
# ETC

# %% [markdown]
# ### Grid3 --> Resampling normalnie I-E

# %%
map1 = {"I": 0, "E": 1}
map2 = {"N": 0, "S": 1}
map3 = {"T": 0, "F": 1}
map4 = {"J": 0, "P": 1}
df['I-E'] = df['type'].astype(str).str[0]
df['I-E'] = df['I-E'].map(map1)
df['N-S'] = df['type'].astype(str).str[1]
df['N-S'] = df['N-S'].map(map2)
df['T-F'] = df['type'].astype(str).str[2]
df['T-F'] = df['T-F'].map(map3)
df['J-P'] = df['type'].astype(str).str[3]
df['J-P'] = df['J-P'].map(map4)
df.head(10)
# Out:
#    type                                              posts  words_per_post  \
# 0  INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...           11.12
# 1  ENTP  'I'm finding the lack of me in these posts ver...           23.40
# 2  INTP  'Good one  _____   https://www.youtube.com/wat...           16.72
# 3  INTJ  'Dear INTP,   I enjoyed our conversation the o...           21.28
# 4  ENTJ  'You're fired.|||That's another silly misconce...           19.34
# 5  INTJ  '18/37 @.@|||Science  is not perfect. No scien...           29.82
# 6  INFJ  'No, I can't draw on my own nails (haha). Thos...           26.58
# 7  INTJ  'I tend to build up a collection of things on ...           24.46
# 8  INFJ  I'm not sure, that's a good question. The dist...           14.76
# 9  INTP  'https://www.youtube.com/watch?v=w8-egj0y8Qs||...           24.66
#
#    ... per Post  http per Post  music per Post  jpg per Post  I per Post  I-E  \
# 0          0.30           0.48            0.02          0.12        0.46    0
# 1          0.38           0.20            0.00          0.02        2.02    1
# 2          0.26           0.10            0.00          0.00        0.98    0
# 3          0.52           0.04            0.02          0.00        1.74    0
# 4          0.42           0.12            0.02          0.04        0.92    1
# 5          0.78           0.02            0.00          0.00        1.88    0
# 6          0.74           0.04            0.02          0.00        1.88    0
# 7          0.56           0.02            0.04          0.00        0.32    0
# 8          0.34           0.46            0.02          0.02        0.98    0
# 9          0.48           0.14            0.02          0.00        0.20    0
#
#    N-S  T-F  J-P
# 0    0    1    0
# 1    0    0    1
# 2    0    0    1
# 3    0    0    0
# 4    0    0    0
# 5    0    0    0
# 6    0    1    0
# 7    0    0    0
# 8    0    1    0
# 9    0    0    1

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import chi2
from imblearn.under_sampling import NearMiss
from imblearn.over_sampling import SMOTE

XX = df.drop(['type','posts','clean_posts','I-E','N-S','T-F','J-P'], axis=1).values
yy = df['I-E'].values

print(XX.shape)
print(yy.shape)

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(XX,yy,test_size = 0.1, random_state=42)

nm1 = NearMiss(version=1)
sm = SMOTE()
X_train_res, y_train_res = sm.fit_sample(X_train, y_train)
#X_test_res, y_test_res = sm.fit_sample(X_test, y_test)

from sklearn.preprocessing import StandardScaler

X_std = StandardScaler().fit_transform(X_train_res)
X_std_test = StandardScaler().fit_transform(X_test)


from sklearn.decomposition import PCA
model = PCA()

pca_features_train = model.fit_transform(X_std) # dwa wymiary, wiec rzutowanie jest na dwa wymiary
pca_features_test = model.fit_transform(X_std_test)

print(pca_features.shape)
X_train_res = pca_features_train
X_test = pca_features_test
#print(y_train_res)
print(y_test.shape)
# Out:
# (8675, 6)
# (8675,)
# (11986, 6)
# (868,)

# %%
from sklearn.model_selection import StratifiedKFold
seed=123
kfold = StratifiedKFold(n_splits=5, random_state=seed)

param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}
param_grid2 = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'penalty': ['none','l2']}
param_grid3 = {'max_leaf_nodes': [10, 16, 32, 64, 80]}

param_grid4 = {'n_estimators': [100,200,300,400,500,600,700,800,900,1000],'max_leaf_nodes' : [2,48,16,32,64]}


from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

#grid_1_res_normal_IE = GridSearchCV(SVC(kernel = 'rbf',probability=True), param_grid, cv=kfold, return_train_score=True)
grid_2_res_normal_IE = GridSearchCV(LogisticRegression(), param_grid2, cv=kfold, return_train_score=True)
grid_3_res_normal_IE = GridSearchCV(ExtraTreesClassifier(), param_grid4, cv=kfold, return_train_score=True)


#grid_1_res_normal_IE.fit(X_train_res, y_train_res)
#print(grid_1_res_normal_IE .best_params_)

grid_2_res_normal_IE.fit(X_train_res, y_train_res)
print(grid_2_res_normal_IE .best_params_)

grid_3_res_normal_IE.fit(X_train_res, y_train_res)
print(grid_3_res_normal_IE .best_params_)
# Out:
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# {'C': 10, 'penalty': 'l2'}
# {'max_leaf_nodes': 64, 'n_estimators': 200}

# %%
#Pokazujemy Dokładność Modelu


from sklearn import  metrics

models_res = []
#models_res.append(('SVM rbf', grid_1_res_normal_IE.best_estimator_))
models_res.append(('LogReg', grid_2_res_normal_IE.best_estimator_))
models_res.append(('RND', grid_3_res_normal_IE.best_estimator_))




precision_score = []
recall_score = []
f1_score = []
accuracy_score = []
for name, model in models_res:
    print(name)
    print("R^2: {}".format(metrics.precision_score(y_test, model.predict(X_test),average='micro') ))
    print("recall_score: {}".format( metrics.recall_score(y_test, model.predict(X_test),average='micro') ))
    print("f1_score: {}".format( metrics.f1_score(y_test, model.predict(X_test),average='micro') ))
    print("accuracy_score: {}".format( metrics.accuracy_score(y_test, model.predict(X_test)) ))
    precision_score.append(metrics.precision_score(y_test, model.predict(X_test),average='micro'))
    recall_score.append(metrics.recall_score(y_test, model.predict(X_test),average='micro'))
    f1_score.append( metrics.f1_score(y_test, model.predict(X_test),average='micro'))
    accuracy_score.append(metrics.accuracy_score(y_test, model.predict(X_test)))
    
    import seaborn as sn
    import pandas as pd
    import matplotlib.pyplot as plt
    array =metrics.confusion_matrix(y_test, model.predict(X_test))

    personality_types = np.unique(y_test)

    df_cm = pd.DataFrame(array, index = [i for i in personality_types],
                      columns = [i for i in personality_types])

    plt.figure(figsize = (15,15))
    heatmap(array, xlabel='True', xticklabels=personality_types, ylabel='Predicted', yticklabels=personality_types, cmap="plasma")
    plt.show()
# Out:
# LogReg
# R^2: 0.5126728110599078
# recall_score: 0.5126728110599078
# f1_score: 0.5126728110599078
# accuracy_score: 0.5126728110599078
# RND
# R^2: 0.6370967741935484
# recall_score: 0.6370967741935484
# f1_score: 0.6370967741935484
# accuracy_score: 0.6370967741935484

# %%
"""print("SVM")
results1 = pd.DataFrame(grid_1_res_normal_IE.cv_results_)

scores1 = np.array(results1.mean_test_score).reshape(6, 6)

heatmap(scores1, xlabel='gamma', xticklabels=param_grid['gamma'], ylabel='C', yticklabels=param_grid['C'], cmap="plasma")
plt.show()"""
print("LogReg")

results2 = pd.DataFrame(grid_2_res_normal_IE.cv_results_)

scores2 = np.array(results2.mean_test_score).reshape(6, 2)

heatmap(scores2, xlabel='gamma', xticklabels=param_grid2['penalty'], ylabel='C', yticklabels=param_grid2['C'], cmap="plasma")
plt.show()
print("ETC")

results3 = pd.DataFrame(grid_3_res_normal_IE.cv_results_)

scores3 = np.array(results3.mean_test_score).reshape(5, 10)

heatmap(scores3, xlabel='n_estimators', xticklabels=param_grid4['n_estimators'], ylabel='max_leaf_nodes', yticklabels=param_grid4['max_leaf_nodes'], cmap="plasma")
plt.show()
# Out:
# LogReg
# ETC

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import chi2
from imblearn.under_sampling import NearMiss
from imblearn.over_sampling import SMOTE

XX = df.drop(['type','posts','clean_posts','I-E','N-S','T-F','J-P'], axis=1).values
yy = df['N-S'].values

print(XX.shape)
print(yy.shape)

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(XX,yy,test_size = 0.1, random_state=42)

nm1 = NearMiss(version=1)
sm = SMOTE()
X_train_res, y_train_res = sm.fit_sample(X_train, y_train)
#X_test_res, y_test_res = sm.fit_sample(X_test, y_test)

from sklearn.preprocessing import StandardScaler

X_std = StandardScaler().fit_transform(X_train_res)
X_std_test = StandardScaler().fit_transform(X_test)


from sklearn.decomposition import PCA
model = PCA()

pca_features_train = model.fit_transform(X_std) # dwa wymiary, wiec rzutowanie jest na dwa wymiary
pca_features_test = model.fit_transform(X_std_test)

print(pca_features.shape)
X_train_res = pca_features_train
X_test = pca_features_test
#print(y_train_res)
print(y_test.shape)
# Out:
# (8675, 6)
# (8675,)
# (13462, 6)
# (868,)

# %%
from sklearn.model_selection import StratifiedKFold
seed=123
kfold = StratifiedKFold(n_splits=5, random_state=seed)

param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}
param_grid2 = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'penalty': ['none','l2']}
param_grid3 = {'max_leaf_nodes': [10, 16, 32, 64, 80]}

param_grid4 = {'n_estimators': [100,200,300,400,500,600,700,800,900,1000],'max_leaf_nodes' : [2,48,16,32,64]}


from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

#grid_1_res_normal_NS = GridSearchCV(SVC(kernel = 'rbf',probability=True), param_grid, cv=kfold, return_train_score=True)
grid_2_res_normal_NS = GridSearchCV(LogisticRegression(), param_grid2, cv=kfold, return_train_score=True)
grid_3_res_normal_NS = GridSearchCV(ExtraTreesClassifier(), param_grid4, cv=kfold, return_train_score=True)


#grid_1_res_normal_NS.fit(X_train_res, y_train_res)
#print(grid_1_res_normal_NS.best_params_)

grid_2_res_normal_NS.fit(X_train_res, y_train_res)
print(grid_2_res_normal_NS.best_params_)

grid_3_res_normal_NS.fit(X_train_res, y_train_res)
print(grid_3_res_normal_NS.best_params_)
# Out:
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# {'C': 10, 'penalty': 'l2'}
# {'max_leaf_nodes': 64, 'n_estimators': 1000}

# %%
#Pokazujemy Dokładność Modelu


from sklearn import  metrics

models_res = []
#models_res.append(('SVM rbf', grid_1_res_normal_NS.best_estimator_))
models_res.append(('LogReg', grid_2_res_normal_NS.best_estimator_))
models_res.append(('RND', grid_3_res_normal_NS.best_estimator_))




precision_score = []
recall_score = []
f1_score = []
accuracy_score = []
for name, model in models_res:
    print(name)
    print("R^2: {}".format(metrics.precision_score(y_test, model.predict(X_test),average='micro') ))
    print("recall_score: {}".format( metrics.recall_score(y_test, model.predict(X_test),average='micro') ))
    print("f1_score: {}".format( metrics.f1_score(y_test, model.predict(X_test),average='micro') ))
    print("accuracy_score: {}".format( metrics.accuracy_score(y_test, model.predict(X_test)) ))
    precision_score.append(metrics.precision_score(y_test, model.predict(X_test),average='micro'))
    recall_score.append(metrics.recall_score(y_test, model.predict(X_test),average='micro'))
    f1_score.append( metrics.f1_score(y_test, model.predict(X_test),average='micro'))
    accuracy_score.append(metrics.accuracy_score(y_test, model.predict(X_test)))
    
    import seaborn as sn
    import pandas as pd
    import matplotlib.pyplot as plt
    array =metrics.confusion_matrix(y_test, model.predict(X_test))

    personality_types = np.unique(y_test)

    df_cm = pd.DataFrame(array, index = [i for i in personality_types],
                      columns = [i for i in personality_types])

    plt.figure(figsize = (15,15))
    heatmap(array, xlabel='True', xticklabels=personality_types, ylabel='Predicted', yticklabels=personality_types, cmap="plasma")
    plt.show()
# Out:
# LogReg
# R^2: 0.5368663594470046
# recall_score: 0.5368663594470046
# f1_score: 0.5368663594470046
# accuracy_score: 0.5368663594470046
# RND
# R^2: 0.7327188940092166
# recall_score: 0.7327188940092166
# f1_score: 0.7327188940092166
# accuracy_score: 0.7327188940092166

# %%
"""print("SVM")
results1 = pd.DataFrame(grid_1_res_normal_NS.cv_results_)

scores1 = np.array(results1.mean_test_score).reshape(6, 6)

heatmap(scores1, xlabel='gamma', xticklabels=param_grid['gamma'], ylabel='C', yticklabels=param_grid['C'], cmap="plasma")
plt.show()"""
print("LogReg")

results2 = pd.DataFrame(grid_2_res_normal_NS.cv_results_)

scores2 = np.array(results2.mean_test_score).reshape(6, 2)

heatmap(scores2, xlabel='gamma', xticklabels=param_grid2['penalty'], ylabel='C', yticklabels=param_grid2['C'], cmap="plasma")
plt.show()
print("ETC")

results3 = pd.DataFrame(grid_3_res_normal_NS.cv_results_)

scores3 = np.array(results3.mean_test_score).reshape(5, 10)

heatmap(scores3, xlabel='n_estimators', xticklabels=param_grid4['n_estimators'], ylabel='max_leaf_nodes', yticklabels=param_grid4['max_leaf_nodes'], cmap="plasma")
plt.show()
# Out:
# LogReg
# ETC

# %%
svmm = SVC(kernel = 'rbf',probability=True, C = 100, gamma = 0.001)
svmm.fit(X_train_res, y_train_res)
print(name)
print("R^2: {}".format(metrics.precision_score(y_test, svmm.predict(X_test),average='micro') ))
print("recall_score: {}".format( metrics.recall_score(y_test, svmm.predict(X_test),average='micro') ))
print("f1_score: {}".format( metrics.f1_score(y_test, svmm.predict(X_test),average='micro') ))
print("accuracy_score: {}".format( metrics.accuracy_score(y_test, svmm.predict(X_test)) ))

import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
array =metrics.confusion_matrix(y_test, svmm.predict(X_test))

personality_types = np.unique(y_test)

df_cm = pd.DataFrame(array, index = [i for i in personality_types],
                  columns = [i for i in personality_types])

plt.figure(figsize = (15,15))
heatmap(array, xlabel='True', xticklabels=personality_types, ylabel='Predicted', yticklabels=personality_types, cmap="plasma")
plt.show()
# Out:
# RND
# R^2: 0.5357142857142857
# recall_score: 0.5357142857142857
# f1_score: 0.5357142857142857
# accuracy_score: 0.5357142857142857

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import chi2
from imblearn.under_sampling import NearMiss
from imblearn.over_sampling import SMOTE

XX = df.drop(['type','posts','clean_posts','I-E','N-S','T-F','J-P'], axis=1).values
yy = df['T-F'].values

print(XX.shape)
print(yy.shape)

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(XX,yy,test_size = 0.1, random_state=42)

nm1 = NearMiss(version=1)
sm = SMOTE()
X_train_res, y_train_res = sm.fit_sample(X_train, y_train)
#X_test_res, y_test_res = sm.fit_sample(X_test, y_test)

from sklearn.preprocessing import StandardScaler

X_std = StandardScaler().fit_transform(X_train_res)
X_std_test = StandardScaler().fit_transform(X_test)


from sklearn.decomposition import PCA
model = PCA()

pca_features_train = model.fit_transform(X_std) # dwa wymiary, wiec rzutowanie jest na dwa wymiary
pca_features_test = model.fit_transform(X_std_test)

print(pca_features.shape)
X_train_res = pca_features_train
X_test = pca_features_test
#print(y_train_res)
print(y_test.shape)
# Out:
# (8675, 6)
# (8675,)
# (8458, 6)
# (868,)

# %%
from sklearn.model_selection import StratifiedKFold
seed=123
kfold = StratifiedKFold(n_splits=5, random_state=seed)

param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}
param_grid2 = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'penalty': ['none','l2']}
param_grid3 = {'max_leaf_nodes': [10, 16, 32, 64, 80]}

param_grid4 = {'n_estimators': [100,200,300,400,500,600,700,800,900,1000],'max_leaf_nodes' : [2,48,16,32,64]}


from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

#grid_1_res_normal_TF = GridSearchCV(SVC(kernel = 'rbf',probability=True), param_grid, cv=kfold, return_train_score=True)
grid_2_res_normal_TF = GridSearchCV(LogisticRegression(), param_grid2, cv=kfold, return_train_score=True)
grid_3_res_normal_TF = GridSearchCV(ExtraTreesClassifier(), param_grid4, cv=kfold, return_train_score=True)


#grid_1_res_normal_TF.fit(X_train_res, y_train_res)
##print(grid_1_res_normal_TF.best_params_)

grid_2_res_normal_TF.fit(X_train_res, y_train_res)
print(grid_2_res_normal_TF.best_params_)

grid_3_res_normal_TF.fit(X_train_res, y_train_res)
print(grid_3_res_normal_TF.best_params_)
# Out:
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# {'C': 10, 'penalty': 'l2'}
# {'max_leaf_nodes': 64, 'n_estimators': 900}

# %%
#Pokazujemy Dokładność Modelu


from sklearn import  metrics

models_res = []
#models_res.append(('SVM rbf', grid_1_res_normal_TF.best_estimator_))
models_res.append(('LogReg', grid_2_res_normal_TF.best_estimator_))
models_res.append(('RND', grid_3_res_normal_TF.best_estimator_))




precision_score = []
recall_score = []
f1_score = []
accuracy_score = []
for name, model in models_res:
    print(name)
    print("R^2: {}".format(metrics.precision_score(y_test, model.predict(X_test),average='micro') ))
    print("recall_score: {}".format( metrics.recall_score(y_test, model.predict(X_test),average='micro') ))
    print("f1_score: {}".format( metrics.f1_score(y_test, model.predict(X_test),average='micro') ))
    print("accuracy_score: {}".format( metrics.accuracy_score(y_test, model.predict(X_test)) ))
    precision_score.append(metrics.precision_score(y_test, model.predict(X_test),average='micro'))
    recall_score.append(metrics.recall_score(y_test, model.predict(X_test),average='micro'))
    f1_score.append( metrics.f1_score(y_test, model.predict(X_test),average='micro'))
    accuracy_score.append(metrics.accuracy_score(y_test, model.predict(X_test)))
    
    import seaborn as sn
    import pandas as pd
    import matplotlib.pyplot as plt
    array =metrics.confusion_matrix(y_test, model.predict(X_test))

    personality_types = np.unique(y_test)

    df_cm = pd.DataFrame(array, index = [i for i in personality_types],
                      columns = [i for i in personality_types])

    plt.figure(figsize = (15,15))
    heatmap(array, xlabel='True', xticklabels=personality_types, ylabel='Predicted', yticklabels=personality_types, cmap="plasma")
    plt.show()
# Out:
# LogReg
# R^2: 0.5956221198156681
# recall_score: 0.5956221198156681
# f1_score: 0.5956221198156681
# accuracy_score: 0.5956221198156681
# RND
# R^2: 0.5829493087557603
# recall_score: 0.5829493087557603
# f1_score: 0.5829493087557603
# accuracy_score: 0.5829493087557603

# %%
"""print("SVM")
results1 = pd.DataFrame(grid_1_res_normal_TF.cv_results_)

scores1 = np.array(results1.mean_test_score).reshape(6, 6)

heatmap(scores1, xlabel='gamma', xticklabels=param_grid['gamma'], ylabel='C', yticklabels=param_grid['C'], cmap="plasma")
plt.show()"""
print("LogReg")

results2 = pd.DataFrame(grid_2_res_normal_TF.cv_results_)

scores2 = np.array(results2.mean_test_score).reshape(6, 2)

heatmap(scores2, xlabel='gamma', xticklabels=param_grid2['penalty'], ylabel='C', yticklabels=param_grid2['C'], cmap="plasma")
plt.show()
print("ETC")

results3 = pd.DataFrame(grid_3_res_normal_TF.cv_results_)

scores3 = np.array(results3.mean_test_score).reshape(5, 10)

heatmap(scores3, xlabel='n_estimators', xticklabels=param_grid4['n_estimators'], ylabel='max_leaf_nodes', yticklabels=param_grid4['max_leaf_nodes'], cmap="plasma")
plt.show()
# Out:
# LogReg
# ETC

# %%
svmmm = SVC(kernel = 'rbf',probability=True, C = 100, gamma = 100)
svmmm.fit(X_train_res, y_train_res)
print(name)
print("R^2: {}".format(metrics.precision_score(y_test, svmmm.predict(X_test),average='micro') ))
print("recall_score: {}".format( metrics.recall_score(y_test, svmmm.predict(X_test),average='micro') ))
print("f1_score: {}".format( metrics.f1_score(y_test, svmmm.predict(X_test),average='micro') ))
print("accuracy_score: {}".format( metrics.accuracy_score(y_test, svmmm.predict(X_test)) ))

import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
array =metrics.confusion_matrix(y_test, svmmm.predict(X_test))

personality_types = np.unique(y_test)

df_cm = pd.DataFrame(array, index = [i for i in personality_types],
                  columns = [i for i in personality_types])

plt.figure(figsize = (15,15))
heatmap(array, xlabel='True', xticklabels=personality_types, ylabel='Predicted', yticklabels=personality_types, cmap="plasma")
plt.show()
# Out:
# RND
# R^2: 0.5506912442396313
# recall_score: 0.5506912442396313
# f1_score: 0.5506912442396313
# accuracy_score: 0.5506912442396313

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import chi2
from imblearn.under_sampling import NearMiss
from imblearn.over_sampling import SMOTE

XX = df.drop(['type','posts','clean_posts','I-E','N-S','T-F','J-P'], axis=1).values
yy = df['J-P'].values

print(XX.shape)
print(yy.shape)

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(XX,yy,test_size = 0.1, random_state=42)

nm1 = NearMiss(version=1)
sm = SMOTE()
X_train_res, y_train_res = sm.fit_sample(X_train, y_train)
#X_test_res, y_test_res = sm.fit_sample(X_test, y_test)

from sklearn.preprocessing import StandardScaler

X_std = StandardScaler().fit_transform(X_train_res)
X_std_test = StandardScaler().fit_transform(X_test)


from sklearn.decomposition import PCA
model = PCA()

pca_features_train = model.fit_transform(X_std) # dwa wymiary, wiec rzutowanie jest na dwa wymiary
pca_features_test = model.fit_transform(X_std_test)

print(pca_features.shape)
X_train_res = pca_features_train
X_test = pca_features_test
#print(y_train_res)
print(y_test.shape)
# Out:
# (8675, 6)
# (8675,)
# (9410, 6)
# (868,)

# %%
from sklearn.model_selection import StratifiedKFold
seed=123
kfold = StratifiedKFold(n_splits=5, random_state=seed)

param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}
param_grid2 = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'penalty': ['none','l2']}
param_grid3 = {'max_leaf_nodes': [10, 16, 32, 64, 80]}

param_grid4 = {'n_estimators': [100,200,300,400,500,600,700,800,900,1000],'max_leaf_nodes' : [2,48,16,32,64]}


from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

#grid_1_res_normal_JP = GridSearchCV(SVC(kernel = 'rbf',probability=True), param_grid, cv=kfold, return_train_score=True)
grid_2_res_normal_JP = GridSearchCV(LogisticRegression(), param_grid2, cv=kfold, return_train_score=True)
grid_3_res_normal_JP = GridSearchCV(ExtraTreesClassifier(), param_grid4, cv=kfold, return_train_score=True)

#
#grid_1_res_normal_JP.fit(X_train_res, y_train_res)
#print(grid_1_res_normal_JP.best_params_)

grid_2_res_normal_JP.fit(X_train_res, y_train_res)
print(grid_2_res_normal_JP.best_params_)

grid_3_res_normal_JP.fit(X_train_res, y_train_res)
print(grid_3_res_normal_JP.best_params_)
# Out:
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# {'C': 1, 'penalty': 'l2'}
# {'max_leaf_nodes': 64, 'n_estimators': 600}

# %%
#Pokazujemy Dokładność Modelu


from sklearn import  metrics

models_res = []
#models_res.append(('SVM rbf', grid_1_res_normal_JP.best_estimator_))
models_res.append(('LogReg', grid_2_res_normal_JP.best_estimator_))
models_res.append(('RND', grid_3_res_normal_JP.best_estimator_))




precision_score = []
recall_score = []
f1_score = []
accuracy_score = []
for name, model in models_res:
    print(name)
    print("R^2: {}".format(metrics.precision_score(y_test, model.predict(X_test),average='micro') ))
    print("recall_score: {}".format( metrics.recall_score(y_test, model.predict(X_test),average='micro') ))
    print("f1_score: {}".format( metrics.f1_score(y_test, model.predict(X_test),average='micro') ))
    print("accuracy_score: {}".format( metrics.accuracy_score(y_test, model.predict(X_test)) ))
    precision_score.append(metrics.precision_score(y_test, model.predict(X_test),average='micro'))
    recall_score.append(metrics.recall_score(y_test, model.predict(X_test),average='micro'))
    f1_score.append( metrics.f1_score(y_test, model.predict(X_test),average='micro'))
    accuracy_score.append(metrics.accuracy_score(y_test, model.predict(X_test)))
    
    import seaborn as sn
    import pandas as pd
    import matplotlib.pyplot as plt
    array =metrics.confusion_matrix(y_test, model.predict(X_test))

    personality_types = np.unique(y_test)

    df_cm = pd.DataFrame(array, index = [i for i in personality_types],
                      columns = [i for i in personality_types])

    plt.figure(figsize = (15,15))
    heatmap(array, xlabel='True', xticklabels=personality_types, ylabel='Predicted', yticklabels=personality_types, cmap="plasma")
    plt.show()
# Out:
# LogReg
# R^2: 0.532258064516129
# recall_score: 0.532258064516129
# f1_score: 0.532258064516129
# accuracy_score: 0.532258064516129
# RND
# R^2: 0.5610599078341014
# recall_score: 0.5610599078341014
# f1_score: 0.5610599078341014
# accuracy_score: 0.5610599078341014

# %%
"""print("SVM")
results1 = pd.DataFrame(grid_1_res_normal_JP.cv_results_)

scores1 = np.array(results1.mean_test_score).reshape(6, 6)

heatmap(scores1, xlabel='gamma', xticklabels=param_grid['gamma'], ylabel='C', yticklabels=param_grid['C'], cmap="plasma")
plt.show()"""
print("LogReg")

results2 = pd.DataFrame(grid_2_res_normal_JP.cv_results_)

scores2 = np.array(results2.mean_test_score).reshape(6, 2)

heatmap(scores2, xlabel='gamma', xticklabels=param_grid2['penalty'], ylabel='C', yticklabels=param_grid2['C'], cmap="plasma")
plt.show()
print("ETC")

results3 = pd.DataFrame(grid_3_res_normal_JP.cv_results_)

scores3 = np.array(results3.mean_test_score).reshape(5, 10)

heatmap(scores3, xlabel='n_estimators', xticklabels=param_grid4['n_estimators'], ylabel='max_leaf_nodes', yticklabels=param_grid4['max_leaf_nodes'], cmap="plasma")
plt.show()
# Out:
# LogReg
# ETC

# %% [markdown]
# ### Selekcja Automatyczna:

# %%
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from bs4 import BeautifulSoup
from sklearn.model_selection import cross_validate
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import learning_curve
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB

from sklearn.model_selection import GridSearchCV
def cleanText(text):
    text = BeautifulSoup(text, "lxml").text
    text = re.sub(r'\|\|\|', r' ', text) 
    text = re.sub(r'http\S+', r'<URL>', text)
    return text
df['clean_posts'] = df['posts'].apply(cleanText)

# %%
#Czyścimy zbiór Danych z  niepotrzebnych linków itp.

XX = df['clean_posts'].values
yy = df['type'].values

print(XX.shape)
print(yy.shape)

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(XX,yy,test_size = 0.1, random_state=42)
#Przeprowadzamy Text Mining oraz Skalowanie danych i redukcje wymiarów

TfidVect  = tfidf.fit_transform(X_train)
svd_model = tsvd
data_revitalised = svd_model.fit_transform(TfidVect)

TfidVect_test  = tfidf.fit_transform(X_test)
svd_model_test = tsvd
data_revitalised_test = svd_model_test.fit_transform(TfidVect_test)

sm = SMOTE()
X_train_res, y_train_res = sm.fit_sample(data_revitalised, y_train)

from sklearn.preprocessing import StandardScaler

X_std = StandardScaler().fit_transform(X_train_res)
X_std_test = StandardScaler().fit_transform(X_test)


from sklearn.decomposition import PCA
model = PCA()

pca_features_train = model.fit_transform(X_std) # dwa wymiary, wiec rzutowanie jest na dwa wymiary
pca_features_test = model.fit_transform(X_std_test)

print(pca_features.shape)
X_train_res = pca_features_train
X_test = pca_features_test
#print(y_train_res)
print(y_test.shape)

# %%
from sklearn.model_selection import StratifiedKFold
seed=123
kfold = StratifiedKFold(n_splits=5, random_state=seed)

param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}
param_grid2 = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'penalty': ['none','l2']}
param_grid3 = {'max_leaf_nodes': [10, 16, 32, 64, 80]}

param_grid4 = {'n_estimators': [100,200,300,400,500,600,700,800,900,1000],'max_leaf_nodes' : [2,48,16,32,64]}


from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

grid_1_res_Automatic = GridSearchCV(SVC(kernel = 'rbf',probability=True), param_grid, cv=kfold, return_train_score=True)
grid_2_res_Automatic = GridSearchCV(LogisticRegression(), param_grid2, cv=kfold, return_train_score=True)
grid_3_res_Automatic = GridSearchCV(ExtraTreesClassifier(), param_grid4, cv=kfold, return_train_score=True)


grid_1_res_Automatic.fit(X_train_res, y_train_res)
print(grid_1_res_Automatic.best_params_)

grid_2_res_Automatic.fit(X_train_res, y_train_res)
print(grid_2_res_Automatic.best_params_)

grid_3_res_Automatic.fit(X_train_res, y_train_res)
print(grid_3_res_Automatic.best_params_)

# %%
#Pokazujemy Dokładność Modelu


from sklearn import  metrics

models_res = []
models_res.append(('SVM rbf', grid_1_res_Automatic.best_estimator_))
models_res.append(('LogReg', grid_2_res_Automatic.best_estimator_))
models_res.append(('RND', grid_3_res_Automatic.best_estimator_))


precision_score = []
recall_score = []
f1_score = []
accuracy_score = []
for name, model in models_res_chosen:
    print(name)
    print("R^2: {}".format(metrics.precision_score(y_test, model.predict(X_test),average='micro') ))
    print("recall_score: {}".format( metrics.recall_score(y_test, model.predict(X_test),average='micro') ))
    print("f1_score: {}".format( metrics.f1_score(y_test, model.predict(X_test),average='micro') ))
    print("accuracy_score: {}".format( metrics.accuracy_score(y_test, model.predict(X_test)) ))
    precision_score.append(metrics.precision_score(y_test, model.predict(X_test),average='micro'))
    recall_score.append(metrics.recall_score(y_test, model.predict(X_test),average='micro'))
    f1_score.append( metrics.f1_score(y_test, model.predict(X_test),average='micro'))
    accuracy_score.append(metrics.accuracy_score(y_test, model.predict(X_test)))
    
    import seaborn as sn
    import pandas as pd
    import matplotlib.pyplot as plt
    array =metrics.confusion_matrix(y_test, model.predict(X_test))

    personality_types = np.unique(y_test)

    df_cm = pd.DataFrame(array, index = [i for i in personality_types],
                      columns = [i for i in personality_types])

    plt.figure(figsize = (15,15))
    heatmap(array, xlabel='True', xticklabels=personality_types, ylabel='Predicted', yticklabels=personality_types, cmap="plasma")
    plt.show()

# %%
print("SVM")
results1 = pd.DataFrame(grid_1_res_Automatic.cv_results_)

scores1 = np.array(results1.mean_test_score).reshape(6, 6)

heatmap(scores1, xlabel='gamma', xticklabels=param_grid['gamma'], ylabel='C', yticklabels=param_grid['C'], cmap="plasma")
plt.show()
print("LogReg")

results2 = pd.DataFrame(grid_2_res_Automatic.cv_results_)

scores2 = np.array(results2.mean_test_score).reshape(6, 2)

heatmap(scores2, xlabel='gamma', xticklabels=param_grid2['penalty'], ylabel='C', yticklabels=param_grid2['C'], cmap="plasma")
plt.show()
print("ETC")

results3 = pd.DataFrame(grid_3_res_Automatic.cv_results_)

scores3 = np.array(results3.mean_test_score).reshape(5, 10)

heatmap(scores3, xlabel='n_estimators', xticklabels=param_grid4['n_estimators'], ylabel='max_leaf_nodes', yticklabels=param_grid4['max_leaf_nodes'], cmap="plasma")
plt.show()

# %%
#Czyścimy zbiór Danych z  niepotrzebnych linków itp.

XX = df['clean_posts'].values
yy = df['I-E'].values

print(XX.shape)
print(yy.shape)

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(XX,yy,test_size = 0.1, random_state=42)
#Przeprowadzamy Text Mining oraz Skalowanie danych i redukcje wymiarów

TfidVect  = tfidf.fit_transform(X_train)
svd_model = tsvd
data_revitalised = svd_model.fit_transform(TfidVect)

TfidVect_test  = tfidf.fit_transform(X_test)
svd_model_test = tsvd
data_revitalised_test = svd_model_test.fit_transform(TfidVect_test)

sm = SMOTE()
X_train_res, y_train_res = sm.fit_sample(data_revitalised, y_train)

from sklearn.preprocessing import StandardScaler

X_std = StandardScaler().fit_transform(X_train_res)
X_std_test = StandardScaler().fit_transform(X_test)


from sklearn.decomposition import PCA
model = PCA()

pca_features_train = model.fit_transform(X_std) # dwa wymiary, wiec rzutowanie jest na dwa wymiary
pca_features_test = model.fit_transform(X_std_test)

print(pca_features.shape)
X_train_res = pca_features_train
X_test = pca_features_test
#print(y_train_res)
print(y_test.shape)
# Out:
# (8675,)
# (8675,)

# %%
from sklearn.model_selection import StratifiedKFold
seed=123
kfold = StratifiedKFold(n_splits=5, random_state=seed)

param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}
param_grid2 = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'penalty': ['none','l2']}
param_grid3 = {'max_leaf_nodes': [10, 16, 32, 64, 80]}

param_grid4 = {'n_estimators': [100,200,300,400,500,600,700,800,900,1000],'max_leaf_nodes' : [2,48,16,32,64]}


from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

grid_1_res_Automatic_IE = GridSearchCV(SVC(kernel = 'rbf',probability=True), param_grid, cv=kfold, return_train_score=True)
grid_2_res_Automatic_IE = GridSearchCV(LogisticRegression(), param_grid2, cv=kfold, return_train_score=True)
grid_3_res_Automatic_IE = GridSearchCV(ExtraTreesClassifier(), param_grid4, cv=kfold, return_train_score=True)


grid_1_res_Automatic_IE.fit(X_train_res, y_train_res)
print(grid_1_res_Automatic_IE.best_params_)

grid_2_res_Automatic_IE.fit(X_train_res, y_train_res)
print(grid_2_res_Automatic_IE.best_params_)

grid_3_res_Automatic_IE.fit(X_train_res, y_train_res)
print(grid_3_res_Automatic_IE.best_params_)
# Out:
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# {'C': 100, 'gamma': 100}
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# {'C': 1, 'penalty': 'l2'}
# {'max_leaf_nodes': 64, 'n_estimators': 800}

# %%
#Pokazujemy Dokładność Modelu


from sklearn import  metrics

models_res = []
models_res.append(('SVM rbf', grid_1_res_Automatic_IE.best_estimator_))
models_res.append(('LogReg', grid_2_res_Automatic_IE.best_estimator_))
models_res.append(('RND', grid_3_res_Automatic_IE.best_estimator_))


precision_score = []
recall_score = []
f1_score = []
accuracy_score = []
for name, model in models_res:
    print(name)
    print("R^2: {}".format(metrics.precision_score(y_test, model.predict(data_revitalised_test),average='micro') ))
    print("recall_score: {}".format( metrics.recall_score(y_test, model.predict(data_revitalised_test),average='micro') ))
    print("f1_score: {}".format( metrics.f1_score(y_test, model.predict(data_revitalised_test),average='micro') ))
    print("accuracy_score: {}".format( metrics.accuracy_score(y_test, model.predict(data_revitalised_test)) ))
    precision_score.append(metrics.precision_score(y_test, model.predict(data_revitalised_test),average='micro'))
    recall_score.append(metrics.recall_score(y_test, model.predict(data_revitalised_test),average='micro'))
    f1_score.append( metrics.f1_score(y_test, model.predict(data_revitalised_test),average='micro'))
    accuracy_score.append(metrics.accuracy_score(y_test, model.predict(data_revitalised_test)))
    
    import seaborn as sn
    import pandas as pd
    import matplotlib.pyplot as plt
    array =metrics.confusion_matrix(y_test, model.predict(data_revitalised_test))

    personality_types = np.unique(y_test)

    df_cm = pd.DataFrame(array, index = [i for i in personality_types],
                      columns = [i for i in personality_types])

    plt.figure(figsize = (8,8))
    heatmap(array, xlabel='True', xticklabels=personality_types, ylabel='Predicted', yticklabels=personality_types, cmap="plasma")
    plt.show()
# Out:
# SVM rbf
# R^2: 0.7119815668202765
# recall_score: 0.7119815668202765
# f1_score: 0.7119815668202765
# accuracy_score: 0.7119815668202765
# LogReg
# R^2: 0.5449308755760369
# recall_score: 0.5449308755760369
# f1_score: 0.5449308755760369
# accuracy_score: 0.5449308755760369
# RND
# R^2: 0.6209677419354839
# recall_score: 0.6209677419354839
# f1_score: 0.6209677419354839
# accuracy_score: 0.6209677419354839

# %%
print("SVM")
results1 = pd.DataFrame(grid_1_res_Automatic_IE.cv_results_)

scores1 = np.array(results1.mean_test_score).reshape(6, 6)

heatmap(scores1, xlabel='gamma', xticklabels=param_grid['gamma'], ylabel='C', yticklabels=param_grid['C'], cmap="plasma")
plt.show()
print("LogReg")

results2 = pd.DataFrame(grid_2_res_Automatic_IE.cv_results_)

scores2 = np.array(results2.mean_test_score).reshape(6, 2)

heatmap(scores2, xlabel='gamma', xticklabels=param_grid2['penalty'], ylabel='C', yticklabels=param_grid2['C'], cmap="plasma")
plt.show()
print("ETC")

results3 = pd.DataFrame(grid_3_res_Automatic_IE.cv_results_)

scores3 = np.array(results3.mean_test_score).reshape(5, 10)

heatmap(scores3, xlabel='n_estimators', xticklabels=param_grid4['n_estimators'], ylabel='max_leaf_nodes', yticklabels=param_grid4['max_leaf_nodes'], cmap="plasma")
plt.show()
# Out:
# SVM
# LogReg
# ETC

# %%
#Czyścimy zbiór Danych z  niepotrzebnych linków itp.

XX = df['clean_posts'].values
yy = df['N-S'].values

print(XX.shape)
print(yy.shape)

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(XX,yy,test_size = 0.1, random_state=42)
#Przeprowadzamy Text Mining oraz Skalowanie danych i redukcje wymiarów

TfidVect  = tfidf.fit_transform(X_train)
svd_model = tsvd
data_revitalised = svd_model.fit_transform(TfidVect)

TfidVect_test  = tfidf.fit_transform(X_test)
svd_model_test = tsvd
data_revitalised_test = svd_model_test.fit_transform(TfidVect_test)

sm = SMOTE()
X_train_res, y_train_res = sm.fit_sample(data_revitalised, y_train)

from sklearn.preprocessing import StandardScaler

X_std = StandardScaler().fit_transform(X_train_res)
X_std_test = StandardScaler().fit_transform(X_test)


from sklearn.decomposition import PCA
model = PCA()

pca_features_train = model.fit_transform(X_std) # dwa wymiary, wiec rzutowanie jest na dwa wymiary
pca_features_test = model.fit_transform(X_std_test)

print(pca_features.shape)
X_train_res = pca_features_train
X_test = pca_features_test
#print(y_train_res)
print(y_test.shape)
# Out:
# (8675,)
# (8675,)

# %%
from sklearn.model_selection import StratifiedKFold
seed=123
kfold = StratifiedKFold(n_splits=5, random_state=seed)

param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}
param_grid2 = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'penalty': ['none','l2']}
param_grid3 = {'max_leaf_nodes': [10, 16, 32, 64, 80]}

param_grid4 = {'n_estimators': [100,200,300,400,500,600,700,800,900,1000],'max_leaf_nodes' : [2,48,16,32,64]}


from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

grid_1_res_Automatic_NS = GridSearchCV(SVC(kernel = 'rbf',probability=True), param_grid, cv=kfold, return_train_score=True)
grid_2_res_Automatic_NS = GridSearchCV(LogisticRegression(), param_grid2, cv=kfold, return_train_score=True)
grid_3_res_Automatic_NS = GridSearchCV(ExtraTreesClassifier(), param_grid4, cv=kfold, return_train_score=True)


grid_1_res_Automatic_NS.fit(X_train_res, y_train_res)
print(grid_1_res_Automatic_NS.best_params_)

grid_2_res_Automatic_NS.fit(X_train_res, y_train_res)
print(grid_2_res_Automatic_NS.best_params_)

grid_3_res_Automatic_NS.fit(X_train_res, y_train_res)
print(grid_3_res_Automatic_NS.best_params_)
# Out:
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# {'C': 100, 'gamma': 100}
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# {'C': 0.001, 'penalty': 'none'}
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-a2df5a98cebd> in <module>()
#      33 print(grid_2_res_Automatic_NS.best_params_)
#      34
# ---> 35 grid_3_res_Automatic_NS.fit(X_train_res, y_train_res)
#      36 print(grid_3_res_Automatic_NS.best_params_)
#      37
#
# NameError: name 'grid_3_res_Automatic_NS' is not defined

# %%
grid_3_res_Automatic_NS = GridSearchCV(ExtraTreesClassifier(), param_grid4, cv=kfold, return_train_score=True)


grid_3_res_Automatic_NS.fit(X_train_res, y_train_res)
print(grid_3_res_Automatic_NS.best_params_)
# Out:
# {'max_leaf_nodes': 64, 'n_estimators': 800}

# %%
#Pokazujemy Dokładność Modelu


from sklearn import  metrics

models_res = []
models_res.append(('SVM rbf', grid_1_res_Automatic_NS.best_estimator_))
models_res.append(('LogReg', grid_2_res_Automatic_NS.best_estimator_))
models_res.append(('RND', grid_3_res_Automatic_NS.best_estimator_))


precision_score = []
recall_score = []
f1_score = []
accuracy_score = []
for name, model in models_res:
    print(name)
    print("R^2: {}".format(metrics.precision_score(y_test, model.predict(data_revitalised_test),average='micro') ))
    print("recall_score: {}".format( metrics.recall_score(y_test, model.predict(data_revitalised_test),average='micro') ))
    print("f1_score: {}".format( metrics.f1_score(y_test, model.predict(data_revitalised_test),average='micro') ))
    print("accuracy_score: {}".format( metrics.accuracy_score(y_test, model.predict(data_revitalised_test)) ))
    precision_score.append(metrics.precision_score(y_test, model.predict(data_revitalised_test),average='micro'))
    recall_score.append(metrics.recall_score(y_test, model.predict(data_revitalised_test),average='micro'))
    f1_score.append( metrics.f1_score(y_test, model.predict(data_revitalised_test),average='micro'))
    accuracy_score.append(metrics.accuracy_score(y_test, model.predict(data_revitalised_test)))
    
    import seaborn as sn
    import pandas as pd
    import matplotlib.pyplot as plt
    array =metrics.confusion_matrix(y_test, model.predict(data_revitalised_test))

    personality_types = np.unique(y_test)

    df_cm = pd.DataFrame(array, index = [i for i in personality_types],
                      columns = [i for i in personality_types])

    plt.figure(figsize = (15,15))
    heatmap(array, xlabel='True', xticklabels=personality_types, ylabel='Predicted', yticklabels=personality_types, cmap="plasma")
    plt.show()
# Out:
# SVM rbf
# R^2: 0.7868663594470046
# recall_score: 0.7868663594470046
# f1_score: 0.7868663594470046
# accuracy_score: 0.7868663594470046
# LogReg
# R^2: 0.5622119815668203
# recall_score: 0.5622119815668203
# f1_score: 0.5622119815668203
# accuracy_score: 0.5622119815668203
# RND
# R^2: 0.6071428571428571
# recall_score: 0.6071428571428571
# f1_score: 0.6071428571428571
# accuracy_score: 0.6071428571428571

# %%
print("SVM")
results1 = pd.DataFrame(grid_1_res_Automatic_NS.cv_results_)

scores1 = np.array(results1.mean_test_score).reshape(6, 6)

heatmap(scores1, xlabel='gamma', xticklabels=param_grid['gamma'], ylabel='C', yticklabels=param_grid['C'], cmap="plasma")
plt.show()
print("LogReg")

results2 = pd.DataFrame(grid_2_res_Automatic_NS.cv_results_)

scores2 = np.array(results2.mean_test_score).reshape(6, 2)

heatmap(scores2, xlabel='gamma', xticklabels=param_grid2['penalty'], ylabel='C', yticklabels=param_grid2['C'], cmap="plasma")
plt.show()
print("ETC")

results3 = pd.DataFrame(grid_3_res_Automatic_NS.cv_results_)

scores3 = np.array(results3.mean_test_score).reshape(5, 10)

heatmap(scores3, xlabel='n_estimators', xticklabels=param_grid4['n_estimators'], ylabel='max_leaf_nodes', yticklabels=param_grid4['max_leaf_nodes'], cmap="plasma")
plt.show()
# Out:
# SVM
# LogReg
# ETC

# %%
#Czyścimy zbiór Danych z  niepotrzebnych linków itp.

XX = df['clean_posts'].values
yy = df['T-F'].values

print(XX.shape)
print(yy.shape)

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(XX,yy,test_size = 0.1, random_state=42)
#Przeprowadzamy Text Mining oraz Skalowanie danych i redukcje wymiarów

TfidVect  = tfidf.fit_transform(X_train)
svd_model = tsvd
data_revitalised = svd_model.fit_transform(TfidVect)

TfidVect_test  = tfidf.fit_transform(X_test)
svd_model_test = tsvd
data_revitalised_test = svd_model_test.fit_transform(TfidVect_test)

sm = SMOTE()
X_train_res, y_train_res = sm.fit_sample(data_revitalised, y_train)

from sklearn.preprocessing import StandardScaler

X_std = StandardScaler().fit_transform(X_train_res)
X_std_test = StandardScaler().fit_transform(X_test)


from sklearn.decomposition import PCA
model = PCA()

pca_features_train = model.fit_transform(X_std) # dwa wymiary, wiec rzutowanie jest na dwa wymiary
pca_features_test = model.fit_transform(X_std_test)

print(pca_features.shape)
X_train_res = pca_features_train
X_test = pca_features_test
#print(y_train_res)
print(y_test.shape)
# Out:
# (8675,)
# (8675,)

# %%
from sklearn.model_selection import StratifiedKFold
seed=123
kfold = StratifiedKFold(n_splits=5, random_state=seed)

param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}
param_grid2 = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'penalty': ['none','l2']}
param_grid3 = {'max_leaf_nodes': [10, 16, 32, 64, 80]}

param_grid4 = {'n_estimators': [100,200,300,400,500,600,700,800,900,1000],'max_leaf_nodes' : [2,48,16,32,64]}


from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

grid_1_res_Automatic_TF = GridSearchCV(SVC(kernel = 'rbf',probability=True), param_grid, cv=kfold, return_train_score=True)
grid_2_res_Automatic_TF = GridSearchCV(LogisticRegression(), param_grid2, cv=kfold, return_train_score=True)
grid_3_res_Automatic_TF = GridSearchCV(ExtraTreesClassifier(), param_grid4, cv=kfold, return_train_score=True)


grid_1_res_Automatic_TF.fit(X_train_res, y_train_res)
print(grid_1_res_Automatic_TF.best_params_)

grid_2_res_Automatic_TF.fit(X_train_res, y_train_res)
print(grid_2_res_Automatic_TF.best_params_)

grid_3_res_Automatic_TF.fit(X_train_res, y_train_res)
print(grid_3_res_Automatic_TF.best_params_)
# Out:
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# {'C': 10, 'gamma': 10}
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1503: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# {'C': 0.001, 'penalty': 'none'}
# {'max_leaf_nodes': 64, 'n_estimators': 100}

# %%
#Pokazujemy Dokładność Modelu


from sklearn import  metrics

models_res = []
models_res.append(('SVM rbf', grid_1_res_Automatic_TF.best_estimator_))
models_res.append(('LogReg', grid_2_res_Automatic_TF.best_estimator_))
models_res.append(('RND', grid_3_res_Automatic_TF.best_estimator_))


precision_score = []
recall_score = []
f1_score = []
accuracy_score = []
for name, model in models_res:
    print(name)
    print("R^2: {}".format(metrics.precision_score(y_test, model.predict(data_revitalised_test),average='micro') ))
    print("recall_score: {}".format( metrics.recall_score(y_test, model.predict(data_revitalised_test),average='micro') ))
    print("f1_score: {}".format( metrics.f1_score(y_test, model.predict(data_revitalised_test),average='micro') ))
    print("accuracy_score: {}".format( metrics.accuracy_score(y_test, model.predict(data_revitalised_test)) ))
    precision_score.append(metrics.precision_score(y_test, model.predict(data_revitalised_test),average='micro'))
    recall_score.append(metrics.recall_score(y_test, model.predict(data_revitalised_test),average='micro'))
    f1_score.append( metrics.f1_score(y_test, model.predict(data_revitalised_test),average='micro'))
    accuracy_score.append(metrics.accuracy_score(y_test, model.predict(data_revitalised_test)))
    
    import seaborn as sn
    import pandas as pd
    import matplotlib.pyplot as plt
    array =metrics.confusion_matrix(y_test, model.predict(data_revitalised_test))

    personality_types = np.unique(y_test)

    df_cm = pd.DataFrame(array, index = [i for i in personality_types],
                      columns = [i for i in personality_types])

    plt.figure(figsize = (15,15))
    heatmap(array, xlabel='True', xticklabels=personality_types, ylabel='Predicted', yticklabels=personality_types, cmap="plasma")
    plt.show()
# Out:
# SVM rbf
# R^2: 0.47235023041474655
# recall_score: 0.47235023041474655
# f1_score: 0.4723502304147465
# accuracy_score: 0.47235023041474655
# LogReg
# R^2: 0.4308755760368664
# recall_score: 0.4308755760368664
# f1_score: 0.4308755760368664
# accuracy_score: 0.4308755760368664
# RND
# R^2: 0.46543778801843316
# recall_score: 0.46543778801843316
# f1_score: 0.46543778801843316
# accuracy_score: 0.46543778801843316

# %%
print("SVM")
results1 = pd.DataFrame(grid_1_res_Automatic_TF.cv_results_)

scores1 = np.array(results1.mean_test_score).reshape(6, 6)

heatmap(scores1, xlabel='gamma', xticklabels=param_grid['gamma'], ylabel='C', yticklabels=param_grid['C'], cmap="plasma")
plt.show()
print("LogReg")

results2 = pd.DataFrame(grid_2_res_Automatic_TF.cv_results_)

scores2 = np.array(results2.mean_test_score).reshape(6, 2)

heatmap(scores2, xlabel='gamma', xticklabels=param_grid2['penalty'], ylabel='C', yticklabels=param_grid2['C'], cmap="plasma")
plt.show()
print("ETC")

results3 = pd.DataFrame(grid_3_res_Automatic_TF.cv_results_)

scores3 = np.array(results3.mean_test_score).reshape(5, 10)

heatmap(scores3, xlabel='n_estimators', xticklabels=param_grid4['n_estimators'], ylabel='max_leaf_nodes', yticklabels=param_grid4['max_leaf_nodes'], cmap="plasma")
plt.show()
# Out:
# SVM
# LogReg
# ETC

# %%
#Czyścimy zbiór Danych z  niepotrzebnych linków itp.

XX = df['clean_posts'].values
yy = df['J-P'].values

print(XX.shape)
print(yy.shape)

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(XX,yy,test_size = 0.1, random_state=42)
#Przeprowadzamy Text Mining oraz Skalowanie danych i redukcje wymiarów

TfidVect  = tfidf.fit_transform(X_train)
svd_model = tsvd
data_revitalised = svd_model.fit_transform(TfidVect)

TfidVect_test  = tfidf.fit_transform(X_test)
svd_model_test = tsvd
data_revitalised_test = svd_model_test.fit_transform(TfidVect_test)

sm = SMOTE()
X_train_res, y_train_res = sm.fit_sample(data_revitalised, y_train)

from sklearn.preprocessing import StandardScaler

X_std = StandardScaler().fit_transform(X_train_res)
X_std_test = StandardScaler().fit_transform(X_test)


from sklearn.decomposition import PCA
model = PCA()

pca_features_train = model.fit_transform(X_std) # dwa wymiary, wiec rzutowanie jest na dwa wymiary
pca_features_test = model.fit_transform(X_std_test)

print(pca_features.shape)
X_train_res = pca_features_train
X_test = pca_features_test
#print(y_train_res)
print(y_test.shape)
# Out:
# (8675,)
# (8675,)

# %%
from sklearn.model_selection import StratifiedKFold
seed=123
kfold = StratifiedKFold(n_splits=5, random_state=seed)

param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}
param_grid2 = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'penalty': ['none','l2']}
param_grid3 = {'max_leaf_nodes': [10, 16, 32, 64, 80]}

param_grid4 = {'n_estimators': [100,200,300,400,500,600,700,800,900,1000],'max_leaf_nodes' : [2,48,16,32,64]}


from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

grid_1_res_Automatic_JP = GridSearchCV(SVC(kernel = 'rbf',probability=True), param_grid, cv=kfold, return_train_score=True)
grid_2_res_Automatic_JP = GridSearchCV(LogisticRegression(), param_grid2, cv=kfold, return_train_score=True)
grid_3_res_Automatic_JP = GridSearchCV(ExtraTreesClassifier(), param_grid4, cv=kfold, return_train_score=True)


grid_1_res_Automatic_JP.fit(X_train_res, y_train_res)
print(grid_1_res_Automaticv.best_params_)

grid_2_res_Automatic_JP.fit(X_train_res, y_train_res)
print(grid_2_res_Automatic_JP.best_params_)

grid_3_res_Automatic_JP.fit(X_train_res, y_train_res)
print(grid_3_res_Automatic_JP.best_params_)
# Out:
# C:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning

# %%
#Pokazujemy Dokładność Modelu


from sklearn import  metrics

models_res = []
models_res.append(('SVM rbf', grid_1_res_Automatic_JP.best_estimator_))
models_res.append(('LogReg', grid_2_res_Automatic_JP.best_estimator_))
models_res.append(('RND', grid_3_res_Automatic_JP.best_estimator_))


precision_score = []
recall_score = []
f1_score = []
accuracy_score = []
for name, model in models_res:
    print(name)
    print("R^2: {}".format(metrics.precision_score(y_test, model.predict(data_revitalised_test),average='micro') ))
    print("recall_score: {}".format( metrics.recall_score(y_test, model.predict(data_revitalised_test),average='micro') ))
    print("f1_score: {}".format( metrics.f1_score(y_test, model.predict(data_revitalised_test),average='micro') ))
    print("accuracy_score: {}".format( metrics.accuracy_score(y_test, model.predict(data_revitalised_test)) ))
    precision_score.append(metrics.precision_score(y_test, model.predict(data_revitalised_test),average='micro'))
    recall_score.append(metrics.recall_score(y_test, model.predict(data_revitalised_test),average='micro'))
    f1_score.append( metrics.f1_score(y_test, model.predict(data_revitalised_test),average='micro'))
    accuracy_score.append(metrics.accuracy_score(y_test, model.predict(data_revitalised_test)))
    
    import seaborn as sn
    import pandas as pd
    import matplotlib.pyplot as plt
    array =metrics.confusion_matrix(y_test, model.predict(data_revitalised_test))

    personality_types = np.unique(y_test)

    df_cm = pd.DataFrame(array, index = [i for i in personality_types],
                      columns = [i for i in personality_types])

    plt.figure(figsize = (15,15))
    heatmap(array, xlabel='True', xticklabels=personality_types, ylabel='Predicted', yticklabels=personality_types, cmap="plasma")
    plt.show()

# %%
print("SVM")
results1 = pd.DataFrame(grid_1_res_Automatic_JP.cv_results_)

scores1 = np.array(results1.mean_test_score).reshape(6, 6)

heatmap(scores1, xlabel='gamma', xticklabels=param_grid['gamma'], ylabel='C', yticklabels=param_grid['C'], cmap="plasma")
plt.show()
print("LogReg")

results2 = pd.DataFrame(grid_2_res_Automatic_JP.cv_results_)

scores2 = np.array(results2.mean_test_score).reshape(6, 2)

heatmap(scores2, xlabel='gamma', xticklabels=param_grid2['penalty'], ylabel='C', yticklabels=param_grid2['C'], cmap="plasma")
plt.show()
print("ETC")

results3 = pd.DataFrame(grid_3_res_Automatic_JP.cv_results_)

scores3 = np.array(results3.mean_test_score).reshape(5, 10)

heatmap(scores3, xlabel='n_estimators', xticklabels=param_grid4['n_estimators'], ylabel='max_leaf_nodes', yticklabels=param_grid4['max_leaf_nodes'], cmap="plasma")
plt.show()
